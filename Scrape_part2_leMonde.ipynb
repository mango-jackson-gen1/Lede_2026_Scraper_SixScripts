# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
response = requests.get("https://www.lemonde.fr/en/#")
doc = BeautifulSoup(response.text, 'html.parser')
print(response.status_code)   # 200 means OK
# Out:
# 200

# %%
stories = doc.find_all(class_= "article")

# %%
len(stories)
# Out:
# 25

# %% [markdown]
# find(class or a tag name / h1, h2)
#
# select = css selector
#
# select_one = multiples options

# %%
rows = []
for story in stories:
    row = {}

    row ['title'] = story.find(class_ ="article__title").text.strip()
    
    try:
        row['link'] = story.find('a')['href']
    except:
        row['link'] = None

    try:
        row['premium'] = story.find(class_ = 'sr-only').text
    except:
        row['premium'] = None
    
    
    try: 
        row['subhead'] = story.find(class_ = 'article__desc').text.strip()
    except:
        row['subhead'] = None

    try:
        row['byline'] = story.find(class_ = 'article__byline').text.strip()
    except:
        row['byline'] = None
    
    img = story.find("img")
    try:
       row['image_url'] = story.find('img')['src']
    except:
       row['image_url'] = None

    try:
        row['article_type'] = story.find(class_ = 'article__type').text
    except:
        row['article_type'] = None





    rows.append(row)


len(rows)
# Out:
# 25

# %%
rows
# Out:
# [{'title': "In Trump's polarized America, empathy faces unanimous opposition",
#   'link': 'https://www.lemonde.fr/en/opinion/article/2026/06/18/in-trump-s-polarized-america-empathy-faces-unanimous-opposition_6754642_23.html',
#   'premium': 'Subscribers only',
#   'subhead': 'Once valued in American public life, empathy now faces criticism from the far right, which sees it as a sign of weakness. The left, too, is questioning its relevance: In a world where brutality prevails, can we still afford to show understanding?',
#   'byline': None,
#   'image_url': 'https://img.lemde.fr/2026/06/12/247/0/1772/1181/400/266/75/0/868ced8_upload-1-p8em0b9frupn-idees-usa-empathie-bonhomme-2026.jpg',
#   'article_type': None},
#  {'title': 'Ending the war with Iran comes at the cost of major US concessions',
#   'link': 'https://www.lemonde.fr/en/international/article/2026/06/18/ending-the-war-with-iran-comes-at-the-cost-of-major-us-concessions_6754629_4.html',
#   'premium': 'Subscribers only',
#   'subhead': None,
#   'byline': None,
#   'image_url': 'https://img.lemde.fr/2026/06/18/0/18/1459/973/398/265/75/0/c2c746f_ftp-1-jisr8krmo6id-5357875-01-06.jpg',
#   'article_type': None},
#  {'title': "French mural honoring 11-year-old Lyhanna's death faces uncertain future despite strong public support",
#   'link': 'https://www.lemonde.fr/en/france/article/2026/06/19/french-mural-honoring-11-year-old-lyhanna-s-death-faces-uncertain-future-despite-strong-public-support_6754646_7.html',
#   'premium': 'Subscribers only',
#   'subhead': None,
#   'byline': None,
#   'image_url': 'https://img.lemde.fr/2026/06/17/0/0/4920/3280/398/265/75/0/0ba972d_upload-1-2gqq9qstginr-maxbestof346828.jpg',
#   'article_type': None},
#  {'title': "Ukrainian drone assault on Moscow undermines Putin's promises of victory",
#   'link': 'https://www.lemonde.fr/en/international/article/2026/06/18/ukrainian-drone-assault-on-moscow-undermines-putin-s-promises-of-victory_6754645_4.html',
#   'premium': 'Subscribers only',
#   'subhead': 'The Russian capital suffered its largest aerial attack since 2022 on Thursday morning. Despite strict internet censorship, some Muscovites are voicing their fears and frustrations quietly, through messaging apps.',
#   'byline': None,
#   'image_url': 'https://img.lemde.fr/2026/06/18/0/0/3936/2624/398/265/75/0/3a96f40_ftp-1-rtvniko3fkkf-5358061-01-06.jpg',
#   'article_type': None},
#  {'title': "Mont-Saint-Michel will no longer be managed by France's National Monuments Center",
#   'link': 'https://www.lemonde.fr/en/culture/article/2026/06/19/mont-saint-michel-will-no-longer-be-managed-by-france-s-national-monuments-center_6754648_30.html',
#   'premium': 'Subscribers only',
#   'subhead': 'Listed as a UNESCO World Heritage site, Mont-Saint-Michel will now be managed exclusively by the public industrial and commercial establishment (EPIC). The iconic Norman landmark was in a months-long standoff between the two operators, EPIC and the National Monuments Center (CMN), which had been jointly managing the site.',
#   'byline': None,
#   'image_url': 'https://img.lemde.fr/2026/06/17/1647/0/5152/3434/398/265/75/0/e282a1c_upload-1-ymorei65jh33-024-5053108.jpg',
#   'article_type': None},
#  {'title': 'Wealthy taxpayers clean out their holdings, keeping their homes, sports cars and gold bars safe',
#   'link': 'https://www.lemonde.fr/en/politics/article/2026/06/19/wealthy-taxpayers-clean-out-their-holdings-keeping-their-homes-sports-cars-and-gold-bars-safe_6754650_5.html',
#   'premium': 'Subscribers only',
#   'subhead': "The new 20% tax on 'luxury' assets held in personal holdings is prompting owners to quickly remove them. As a result, the measure risks bringing in almost nothing.",
#   'byline': None,
#   'image_url': 'https://img.lemde.fr/2026/06/17/0/0/5476/3650/398/265/75/0/92fdf48_upload-1-xqbht0quudv9-2025-05-21t104159z-690339709-up1el5l0tpwpa-rtrmadp-3-filmfestival-cannes.JPG',
#   'article_type': None},
#  {'title': "'Incidents multiply in the Baltic Sea, where the Russian navy 'now operates in a completely overt manner'",
#   'link': 'https://www.lemonde.fr/en/international/article/2026/06/18/incidents-multiply-in-the-baltic-sea-where-the-russian-navy-now-operates-in-a-completely-overt-manner_6754643_4.html',
#   'premium': 'Subscribers only',
#   'subhead': 'After a Russian frigate fired warning shots at a civilian yacht in the English Channel on June 16, Rear Admiral Johan Norlén, chief of staff of the Swedish navy, describes an increasingly tense climate in Baltic waters.',
#   'byline': 'Elise Vincent',
#   'image_url': 'https://img.lemde.fr/2026/06/16/0/0/8256/5504/664/442/75/0/d6c4232_upload-1-0o4vlujgrm2p-000-a9wj7xy.jpg',
#   'article_type': 'Conversation'},
#  {'title': 'As another heatwave hits, French government tries not to appear overwhelmed by climate crisis',
#   'link': 'https://www.lemonde.fr/en/environment/article/2026/06/18/as-heatwave-hits-french-government-tries-not-to-appear-overwhelmed-by-climate-crisis_6754628_114.html',
#   'premium': 'Subscribers only',
#   'subhead': None,
#   'byline': None,
#   'image_url': 'https://img.lemde.fr/2026/06/18/274/0/6571/4380/198/132/95/0/e25542a_upload-1-6lgjw7qilzyi-e25542a-upload-1-wp2ukkmpljfe-kew2026011g0617-1013570.jpg',
#   'article_type': None},
#  {'title': "UN aid chief demands 'dignity' for Gaza population",
#   'link': 'https://www.lemonde.fr/en/international/article/2026/06/19/un-aid-chief-demands-dignity-for-gaza-population_6754647_4.html',
#   'premium': None,
#   'subhead': None,
#   'byline': None,
#   'image_url': 'https://img.lemde.fr/2026/06/18/0/0/6000/4000/198/132/95/0/5530f51_ftp-1-4tvcmuzs0h5s-2026-06-18t181531z-1715076978-rc2fwlaypr9u-rtrmadp-3-israel-palestinians-gaza-ceasefire.JPG',
#   'article_type': None},
#  {'title': "'Last ride': US says goodbye to Air Force One as Qatari jet awaits",
#   'link': 'https://www.lemonde.fr/en/international/article/2026/06/19/last-ride-us-says-goodbye-to-air-force-one-as-qatari-jet-awaits_6754651_4.html',
#   'premium': None,
#   'subhead': None,
#   'byline': None,
#   'image_url': 'https://img.lemde.fr/2026/06/17/0/0/8023/5348/198/132/95/0/a043030_ftp-1-3t3o2jixve9s-6ec7bf0e7a804297a21fcdbfc09896fc-0-baba12b5760a4e55b60a7cac84eead6c.jpg',
#   'article_type': None},
#  {'title': 'Online betting ads are everywhere during the World Cup, but a law could soon ban them during matches',
#   'link': 'https://www.lemonde.fr/en/sports/article/2026/06/19/online-betting-ads-are-everywhere-during-the-world-cup-a-law-could-soon-ban-them-during-matches_6754649_9.html',
#   'premium': 'Subscribers only',
#   'subhead': None,
#   'byline': None,
#   'image_url': 'https://img.lemde.fr/2026/06/18/0/29/3442/2295/198/132/95/0/c2c63ee_upload-1-22c192j0xrwz-2014-05-23t120000z-104215532-gm1ea5n113l01-rtrmadp-3-soccer-world-betting.JPG',
#   'article_type': None},
#  {'title': 'JD Vance slams Israeli critics of US-Iran deal',
#   'link': 'https://www.lemonde.fr/en/international/article/2026/06/18/jd-vance-slams-israeli-critics-of-us-iran-deal_6754644_4.html',
#   'premium': None,
#   'subhead': None,
#   'byline': None,
#   'image_url': None,
#   'article_type': None},
#  {'title': 'Knicks fans flood New York City streets for championship parade',
#   'link': 'https://www.lemonde.fr/en/sports/article/2026/06/18/knicks-fans-flood-new-york-streets-for-championship-parade_6754641_9.html',
#   'premium': None,
#   'subhead': None,
#   'byline': None,
#   'image_url': None,
#   'article_type': None},
#  {'title': 'Judicial investigation opened against former French PM Edouard Philippe',
#   'link': 'https://www.lemonde.fr/en/france/article/2026/06/18/judicial-investigation-opened-against-former-french-pm-edouard-philippe_6754639_7.html',
#   'premium': 'Subscribers only',
#   'subhead': None,
#   'byline': None,
#   'image_url': None,
#   'article_type': None},
#  {'title': 'Macron receives Trump at Château de Versailles to discuss Ukraine',
#   'link': 'https://www.lemonde.fr/en/international/article/2026/06/18/macron-receives-trump-at-chateau-de-versailles-to-discuss-ukraine_6754627_4.html',
#   'premium': 'Subscribers only',
#   'subhead': None,
#   'byline': None,
#   'image_url': None,
#   'article_type': None},
#  {'title': 'Tebnine hospital bears witness to ongoing war in southern Lebanon',
#   'link': 'https://www.lemonde.fr/en/international/article/2026/06/18/tebnine-hospital-bears-witness-to-ongoing-war-in-southern-lebanon_6754617_4.html',
#   'premium': 'Subscribers only',
#   'subhead': None,
#   'byline': None,
#   'image_url': None,
#   'article_type': None},
#  {'title': 'Iran emerges in position of strength after ceasefire signed with US',
#   'link': 'https://www.lemonde.fr/en/opinion/article/2026/06/18/iran-emerges-in-position-of-strength-after-ceasefire-signed-with-us_6754630_23.html',
#   'premium': None,
#   'subhead': None,
#   'byline': None,
#   'image_url': None,
#   'article_type': 'Editorial'},
#  {'title': '2026 World Cup: Cristiano Ronaldo, Luka Modric and Edin Dzeko, still in the game in their 40s',
#   'link': 'https://www.lemonde.fr/en/sports/article/2026/06/18/2026-world-cup-cristiano-ronaldo-luka-modric-and-edin-dzeko-still-in-the-game-in-their-forties_6754609_9.html',
#   'premium': 'Subscribers only',
#   'subhead': None,
#   'byline': None,
#   'image_url': None,
#   'article_type': None},
#  {'title': 'On Donbas front, warehouse manager aims to improve daily life for Ukrainian soldiers',
#   'link': 'https://www.lemonde.fr/en/international/article/2026/06/18/drones-carrying-hard-boiled-eggs-and-dried-meat-on-the-donbas-front-a-warehouse-manager-aims-to-improve-daily-life-for-ukrainian-soldiers_6754616_4.html',
#   'premium': 'Subscribers only',
#   'subhead': None,
#   'byline': None,
#   'image_url': None,
#   'article_type': None},
#  {'title': 'French security replaces Palantir with domestic firm ChapsVision, a complicated choice',
#   'link': 'https://www.lemonde.fr/en/france/article/2026/06/17/french-security-replaces-palantir-with-domestic-firm-chapsvision-a-complicated-choice_6754592_7.html',
#   'premium': 'Subscribers only',
#   'subhead': "Used since the 2015 terrorist attacks, the controversial American company's data analysis software is set to be gradually replaced by that of a French provider. The long-awaited decision presents a significant technological challenge.",
#   'byline': 'Olivier Pinaud',
#   'image_url': 'https://img.lemde.fr/2026/06/11/0/0/6000/4000/664/442/75/0/0acd44a_ftp-1-go54jge26dco-5288516-01-06.jpg',
#   'article_type': 'In Depth'},
#  {'title': "Spielberg's 'Disclosure Day' aliens have nothing to do with those of Trump",
#   'link': 'https://www.lemonde.fr/en/opinion/article/2026/06/16/spielberg-s-disclosure-day-aliens-have-nothing-to-do-with-trump-s_6754566_23.html',
#   'premium': 'Subscribers only',
#   'subhead': "Days before the film was released worldwide, the White House co-opted the imagery of 'aliens' to further its rhetoric and anti-immigration policy.",
#   'byline': 'Jacques Mandelbaum',
#   'image_url': 'https://img.lemde.fr/2026/06/05/1/0/7691/5127/664/442/75/0/8023167_ftp-1-jh2lmagphamp-a2da86c709804460a5a221b810882ffc-0-39ad02a5f3984e88a72a96a919779b99.jpg',
#   'article_type': 'News analysis'},
#  {'title': "French environment minister's absence from public debate underscores government's climate inaction",
#   'link': 'https://www.lemonde.fr/en/environment/article/2026/06/17/french-environment-minister-s-absence-from-public-debate-underscores-government-s-climate-inaction_6754577_114.html',
#   'premium': 'Subscribers only',
#   'subhead': 'Appiointed in October 2025, Monique Barbut is struggling to make her mark. This situation goes beyond her as an individual and highlights how the government has abandoned the issue.',
#   'byline': 'Raphaëlle Besse Desmoulières',
#   'image_url': 'https://img.lemde.fr/2026/06/15/0/0/4176/2784/664/442/75/0/1882319_upload-1-ych61ifl7vl4-075-pinto-adoption260602-npsig.jpg',
#   'article_type': 'In Depth'},
#  {'title': 'Economic and xenophobic: The double threat posed by the Rassemblement National',
#   'link': 'https://www.lemonde.fr/en/opinion/article/2026/06/17/economic-and-xenophobic-the-double-threat-posed-by-the-rassemblement-national_6754591_23.html',
#   'premium': None,
#   'subhead': None,
#   'byline': None,
#   'image_url': None,
#   'article_type': 'Editorial'},
#  {'title': 'French government urged to reveal hidden assets of the rich',
#   'link': 'https://www.lemonde.fr/en/politics/article/2026/06/17/france-no-longer-knows-who-its-wealthiest-citizens-are-government-urged-to-reopen-black-box-on-the-assets-of-the-richest_6754601_5.html',
#   'premium': 'Subscribe',
#   'subhead': None,
#   'byline': None,
#   'image_url': None,
#   'article_type': 'News'},
#  {'title': "'In the US, the contradictions in the alliance between the tech world and the MAGA movement can no longer be suppressed'",
#   'link': 'https://www.lemonde.fr/en/opinion/article/2026/06/17/in-the-us-the-contradictions-in-the-alliance-between-the-tech-world-and-the-maga-movement-can-no-longer-be-suppressed_6754599_23.html',
#   'premium': 'Subscribe',
#   'subhead': None,
#   'byline': None,
#   'image_url': None,
#   'article_type': 'Op-Ed'}]

# %%
import pandas as pd
df = pd.DataFrame(rows)

# %%
df
# Out:
#                                                 title  \
# 0   In Trump's polarized America, empathy faces un...
# 1   Ending the war with Iran comes at the cost of ...
# 2   French mural honoring 11-year-old Lyhanna's de...
# 3   Ukrainian drone assault on Moscow undermines P...
# 4   Mont-Saint-Michel will no longer be managed by...
# 5   Wealthy taxpayers clean out their holdings, ke...
# 6   'Incidents multiply in the Baltic Sea, where t...
# 7   As another heatwave hits, French government tr...
# 8   UN aid chief demands 'dignity' for Gaza popula...
# 9   'Last ride': US says goodbye to Air Force One ...
# 10  Online betting ads are everywhere during the W...
# 11     JD Vance slams Israeli critics of US-Iran deal
# 12  Knicks fans flood New York City streets for ch...
# 13  Judicial investigation opened against former F...
# 14  Macron receives Trump at Château de Versailles...
# 15  Tebnine hospital bears witness to ongoing war ...
# 16  Iran emerges in position of strength after cea...
# 17  2026 World Cup: Cristiano Ronaldo, Luka Modric...
# 18  On Donbas front, warehouse manager aims to imp...
# 19  French security replaces Palantir with domesti...
# 20  Spielberg's 'Disclosure Day' aliens have nothi...
# 21  French environment minister's absence from pub...
# 22  Economic and xenophobic: The double threat pos...
# 23  French government urged to reveal hidden asset...
# 24  'In the US, the contradictions in the alliance...
#
#                                                  link           premium  \
# 0   https://www.lemonde.fr/en/opinion/article/2026...  Subscribers only
# 1   https://www.lemonde.fr/en/international/articl...  Subscribers only
# 2   https://www.lemonde.fr/en/france/article/2026/...  Subscribers only
# 3   https://www.lemonde.fr/en/international/articl...  Subscribers only
# 4   https://www.lemonde.fr/en/culture/article/2026...  Subscribers only
# 5   https://www.lemonde.fr/en/politics/article/202...  Subscribers only
# 6   https://www.lemonde.fr/en/international/articl...  Subscribers only
# 7   https://www.lemonde.fr/en/environment/article/...  Subscribers only
# 8   https://www.lemonde.fr/en/international/articl...               NaN
# 9   https://www.lemonde.fr/en/international/articl...               NaN
# 10  https://www.lemonde.fr/en/sports/article/2026/...  Subscribers only
# 11  https://www.lemonde.fr/en/international/articl...               NaN
# 12  https://www.lemonde.fr/en/sports/article/2026/...               NaN
# 13  https://www.lemonde.fr/en/france/article/2026/...  Subscribers only
# 14  https://www.lemonde.fr/en/international/articl...  Subscribers only
# 15  https://www.lemonde.fr/en/international/articl...  Subscribers only
# 16  https://www.lemonde.fr/en/opinion/article/2026...               NaN
# 17  https://www.lemonde.fr/en/sports/article/2026/...  Subscribers only
# 18  https://www.lemonde.fr/en/international/articl...  Subscribers only
# 19  https://www.lemonde.fr/en/france/article/2026/...  Subscribers only
# 20  https://www.lemonde.fr/en/opinion/article/2026...  Subscribers only
# 21  https://www.lemonde.fr/en/environment/article/...  Subscribers only
# 22  https://www.lemonde.fr/en/opinion/article/2026...               NaN
# 23  https://www.lemonde.fr/en/politics/article/202...         Subscribe
# 24  https://www.lemonde.fr/en/opinion/article/2026...         Subscribe
#
#                                               subhead  \
# 0   Once valued in American public life, empathy n...
# 1                                                 NaN
# 2                                                 NaN
# 3   The Russian capital suffered its largest aeria...
# 4   Listed as a UNESCO World Heritage site, Mont-S...
# 5   The new 20% tax on 'luxury' assets held in per...
# 6   After a Russian frigate fired warning shots at...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Used since the 2015 terrorist attacks, the con...
# 20  Days before the film was released worldwide, t...
# 21  Appiointed in October 2025, Monique Barbut is ...
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#                           byline  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                            NaN
# 6                  Elise Vincent
# 7                            NaN
# 8                            NaN
# 9                            NaN
# 10                           NaN
# 11                           NaN
# 12                           NaN
# 13                           NaN
# 14                           NaN
# 15                           NaN
# 16                           NaN
# 17                           NaN
# 18                           NaN
# 19                Olivier Pinaud
# 20            Jacques Mandelbaum
# 21  Raphaëlle Besse Desmoulières
# 22                           NaN
# 23                           NaN
# 24                           NaN
#
#                                             image_url   article_type
# 0   https://img.lemde.fr/2026/06/12/247/0/1772/118...            NaN
# 1   https://img.lemde.fr/2026/06/18/0/18/1459/973/...            NaN
# 2   https://img.lemde.fr/2026/06/17/0/0/4920/3280/...            NaN
# 3   https://img.lemde.fr/2026/06/18/0/0/3936/2624/...            NaN
# 4   https://img.lemde.fr/2026/06/17/1647/0/5152/34...            NaN
# 5   https://img.lemde.fr/2026/06/17/0/0/5476/3650/...            NaN
# 6   https://img.lemde.fr/2026/06/16/0/0/8256/5504/...   Conversation
# 7   https://img.lemde.fr/2026/06/18/274/0/6571/438...            NaN
# 8   https://img.lemde.fr/2026/06/18/0/0/6000/4000/...            NaN
# 9   https://img.lemde.fr/2026/06/17/0/0/8023/5348/...            NaN
# 10  https://img.lemde.fr/2026/06/18/0/29/3442/2295...            NaN
# 11                                                NaN            NaN
# 12                                                NaN            NaN
# 13                                                NaN            NaN
# 14                                                NaN            NaN
# 15                                                NaN            NaN
# 16                                                NaN      Editorial
# 17                                                NaN            NaN
# 18                                                NaN            NaN
# 19  https://img.lemde.fr/2026/06/11/0/0/6000/4000/...       In Depth
# 20  https://img.lemde.fr/2026/06/05/1/0/7691/5127/...  News analysis
# 21  https://img.lemde.fr/2026/06/15/0/0/4176/2784/...       In Depth
# 22                                                NaN      Editorial
# 23                                                NaN           News
# 24                                                NaN          Op-Ed

# %%
df.to_csv('leMonde.csv', index=False)
