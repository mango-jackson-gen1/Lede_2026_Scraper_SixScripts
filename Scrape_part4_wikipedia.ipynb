# %% [markdown]
# Part 4
#
# PRESIDENTS
#
# Scrape the list of US Presidents from https://en.wikipedia.org/wiki/List_of_presidents_of_the_United_StatesLinks to an external site.. using pandas and save them as a CSV.
#
# Tips
#
# This requires headers and pandas, which is different than the one above.

# %% [markdown]
# Part 1 - testing using request + BeautifulSoup
# Check for
# response.status_code for 200 response = URL + header building was successful for the query

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36" 
}

response = requests.get('https://en.wikipedia.org/wiki/List_of_presidents_of_the_United_States', headers=headers)

doc = BeautifulSoup(response.text, 'html.parser')

# %%
response.status_code  # 200 means OK
# Out:
# 200

# %% [markdown]
# Part 2
# -> Use panda to build URL + Header
# -> use panda's: read_html
#
# pd.read_html(): find and parse HTML tables.

# %%
import pandas as pd

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36"
}

tables = pd.read_html(
    'https://en.wikipedia.org/wiki/List_of_presidents_of_the_United_States',
    storage_options=headers
)

tables
# Out:
# [    No.[a]  Portrait                    Name (birth–death)  \
#  0        1       NaN    George Washington (1732–1799) [19]
#  1        1       NaN    George Washington (1732–1799) [19]
#  2        2       NaN           John Adams (1735–1826) [21]
#  3        3       NaN     Thomas Jefferson (1743–1826) [23]
#  4        3       NaN     Thomas Jefferson (1743–1826) [23]
#  ..     ...       ...                                   ...
#  78      44       NaN           Barack Obama (b. 1961) [75]
#  79      44       NaN           Barack Obama (b. 1961) [75]
#  80      45       NaN  Donald Trump (b. 1946) 1st term [76]
#  81      46       NaN              Joe Biden (b. 1942) [77]
#  82      47       NaN  Donald Trump (b. 1946) 2nd term [76]
#
#                                 Term[16]  Party[b][17]          Party[b][17].1  \
#  0        April 30, 1789 – March 4, 1797           NaN            Unaffiliated
#  1        April 30, 1789 – March 4, 1797           NaN            Unaffiliated
# ...

# %%
len(tables)
# Out:
# 6

# %%
# tables is a list — pick the one you want, e.g.:
df = tables[0]

# %%
df.head(5)
# Out:
#    No.[a]  Portrait                  Name (birth–death)  \
# 0       1       NaN  George Washington (1732–1799) [19]
# 1       1       NaN  George Washington (1732–1799) [19]
# 2       2       NaN         John Adams (1735–1826) [21]
# 3       3       NaN   Thomas Jefferson (1743–1826) [23]
# 4       3       NaN   Thomas Jefferson (1743–1826) [23]
#
#                          Term[16]  Party[b][17]          Party[b][17].1  \
# 0  April 30, 1789 – March 4, 1797           NaN            Unaffiliated
# 1  April 30, 1789 – March 4, 1797           NaN            Unaffiliated
# 2   March 4, 1797 – March 4, 1801           NaN              Federalist
# 3   March 4, 1801 – March 4, 1809           NaN  Democratic- Republican
# 4   March 4, 1801 – March 4, 1809           NaN  Democratic- Republican
#
#   Election   Vice President[18]
# 0  1788–89        John Adams[c]
# 1     1792        John Adams[c]
# 2     1796  Thomas Jefferson[d]
# 3     1800           Aaron Burr
# ...

# %%
#rename columns 

df = df.rename(columns={df.columns[7]: "Vice President"})

# %%
df
# Out:
#     No.[a]  Portrait                    Name (birth–death)  \
# 0        1       NaN    George Washington (1732–1799) [19]
# 1        1       NaN    George Washington (1732–1799) [19]
# 2        2       NaN           John Adams (1735–1826) [21]
# 3        3       NaN     Thomas Jefferson (1743–1826) [23]
# 4        3       NaN     Thomas Jefferson (1743–1826) [23]
# ..     ...       ...                                   ...
# 78      44       NaN           Barack Obama (b. 1961) [75]
# 79      44       NaN           Barack Obama (b. 1961) [75]
# 80      45       NaN  Donald Trump (b. 1946) 1st term [76]
# 81      46       NaN              Joe Biden (b. 1942) [77]
# 82      47       NaN  Donald Trump (b. 1946) 2nd term [76]
#
#                                Term[16]  Party[b][17]          Party[b][17].1  \
# 0        April 30, 1789 – March 4, 1797           NaN            Unaffiliated
# 1        April 30, 1789 – March 4, 1797           NaN            Unaffiliated
# ...
